# %% [markdown]
# # Описание проекта
#
# Подготовить прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. В вашем распоряжении данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Нам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# # 1. Подготовка данных

# %% [markdown]
# ### 1.1 Загрузим необходимые библиотеки, датасет и получим общую информацию

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv('/datasets/gold_recovery_train.csv')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16860 entries, 0 to 16859
# Data columns (total 87 columns):
# date                                                  16860 non-null object
# final.output.concentrate_ag                           16788 non-null float64
# final.output.concentrate_pb                           16788 non-null float64
# final.output.concentrate_sol                          16490 non-null float64
# final.output.concentrate_au                           16789 non-null float64
# final.output.recovery                                 15339 non-null float64
# final.output.tail_ag                                  16794 non-null float64
# final.output.tail_pb                                  16677 non-null float64
# final.output.tail_sol                                 16715 non-null float64
# final.output.tail_au                                  16794 non-null float64
# primary_cleaner.input.sulfate                         15553 non-null float64
# primary_cleaner.input.depressant                      15598 non-null float64
# primary_cleaner.input.feed_size                       16860 non-null float64
# primary_cleaner.input.xanthate                        15875 non-null float64
# primary_cleaner.output.concentrate_ag                 16778 non-null float64
# primary_cleaner.output.concentrate_pb                 16502 non-null float64
# primary_cleaner.output.concentrate_sol                16224 non-null float64
# primary_cleaner.output.concentrate_au                 16778 non-null float64
# primary_cleaner.output.tail_ag                        16777 non-null float64
# primary_cleaner.output.tail_pb                        16761 non-null float64
# primary_cleaner.output.tail_sol                       16579 non-null float64
# primary_cleaner.output.tail_au                        16777 non-null float64
# primary_cleaner.state.floatbank8_a_air                16820 non-null float64
# primary_cleaner.state.floatbank8_a_level              16827 non-null float64
# primary_cleaner.state.floatbank8_b_air                16820 non-null float64
# primary_cleaner.state.floatbank8_b_level              16833 non-null float64
# primary_cleaner.state.floatbank8_c_air                16822 non-null float64
# primary_cleaner.state.floatbank8_c_level              16833 non-null float64
# primary_cleaner.state.floatbank8_d_air                16821 non-null float64
# primary_cleaner.state.floatbank8_d_level              16833 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         16833 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    16833 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    16833 non-null float64
# rougher.calculation.au_pb_ratio                       15618 non-null float64
# rougher.input.feed_ag                                 16778 non-null float64
# rougher.input.feed_pb                                 16632 non-null float64
# rougher.input.feed_rate                               16347 non-null float64
# rougher.input.feed_size                               16443 non-null float64
# rougher.input.feed_sol                                16568 non-null float64
# rougher.input.feed_au                                 16777 non-null float64
# rougher.input.floatbank10_sulfate                     15816 non-null float64
# rougher.input.floatbank10_xanthate                    16514 non-null float64
# rougher.input.floatbank11_sulfate                     16237 non-null float64
# rougher.input.floatbank11_xanthate                    14956 non-null float64
# rougher.output.concentrate_ag                         16778 non-null float64
# rougher.output.concentrate_pb                         16778 non-null float64
# rougher.output.concentrate_sol                        16698 non-null float64
# rougher.output.concentrate_au                         16778 non-null float64
# rougher.output.recovery                               14287 non-null float64
# rougher.output.tail_ag                                14610 non-null float64
# rougher.output.tail_pb                                16778 non-null float64
# rougher.output.tail_sol                               14611 non-null float64
# rougher.output.tail_au                                14611 non-null float64
# rougher.state.floatbank10_a_air                       16807 non-null float64
# rougher.state.floatbank10_a_level                     16807 non-null float64
# rougher.state.floatbank10_b_air                       16807 non-null float64
# rougher.state.floatbank10_b_level                     16807 non-null float64
# rougher.state.floatbank10_c_air                       16807 non-null float64
# rougher.state.floatbank10_c_level                     16814 non-null float64
# rougher.state.floatbank10_d_air                       16802 non-null float64
# rougher.state.floatbank10_d_level                     16809 non-null float64
# rougher.state.floatbank10_e_air                       16257 non-null float64
# rougher.state.floatbank10_e_level                     16809 non-null float64
# rougher.state.floatbank10_f_air                       16802 non-null float64
# rougher.state.floatbank10_f_level                     16802 non-null float64
# secondary_cleaner.output.tail_ag                      16776 non-null float64
# secondary_cleaner.output.tail_pb                      16764 non-null float64
# secondary_cleaner.output.tail_sol                     14874 non-null float64
# secondary_cleaner.output.tail_au                      16778 non-null float64
# secondary_cleaner.state.floatbank2_a_air              16497 non-null float64
# secondary_cleaner.state.floatbank2_a_level            16751 non-null float64
# secondary_cleaner.state.floatbank2_b_air              16705 non-null float64
# secondary_cleaner.state.floatbank2_b_level            16748 non-null float64
# secondary_cleaner.state.floatbank3_a_air              16763 non-null float64
# secondary_cleaner.state.floatbank3_a_level            16747 non-null float64
# secondary_cleaner.state.floatbank3_b_air              16752 non-null float64
# secondary_cleaner.state.floatbank3_b_level            16750 non-null float64
# secondary_cleaner.state.floatbank4_a_air              16731 non-null float64
# secondary_cleaner.state.floatbank4_a_level            16747 non-null float64
# secondary_cleaner.state.floatbank4_b_air              16768 non-null float64
# secondary_cleaner.state.floatbank4_b_level            16767 non-null float64
# secondary_cleaner.state.floatbank5_a_air              16775 non-null float64
# secondary_cleaner.state.floatbank5_a_level            16775 non-null float64
# secondary_cleaner.state.floatbank5_b_air              16775 non-null float64
# secondary_cleaner.state.floatbank5_b_level            16776 non-null float64
# secondary_cleaner.state.floatbank6_a_air              16757 non-null float64
# secondary_cleaner.state.floatbank6_a_level            16775 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 11.2+ MB

# %%
test = pd.read_csv('/datasets/gold_recovery_test.csv')
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5856 entries, 0 to 5855
# Data columns (total 53 columns):
# date                                          5856 non-null object
# primary_cleaner.input.sulfate                 5554 non-null float64
# primary_cleaner.input.depressant              5572 non-null float64
# primary_cleaner.input.feed_size               5856 non-null float64
# primary_cleaner.input.xanthate                5690 non-null float64
# primary_cleaner.state.floatbank8_a_air        5840 non-null float64
# primary_cleaner.state.floatbank8_a_level      5840 non-null float64
# primary_cleaner.state.floatbank8_b_air        5840 non-null float64
# primary_cleaner.state.floatbank8_b_level      5840 non-null float64
# primary_cleaner.state.floatbank8_c_air        5840 non-null float64
# primary_cleaner.state.floatbank8_c_level      5840 non-null float64
# primary_cleaner.state.floatbank8_d_air        5840 non-null float64
# primary_cleaner.state.floatbank8_d_level      5840 non-null float64
# rougher.input.feed_ag                         5840 non-null float64
# rougher.input.feed_pb                         5840 non-null float64
# rougher.input.feed_rate                       5816 non-null float64
# rougher.input.feed_size                       5834 non-null float64
# rougher.input.feed_sol                        5789 non-null float64
# rougher.input.feed_au                         5840 non-null float64
# rougher.input.floatbank10_sulfate             5599 non-null float64
# rougher.input.floatbank10_xanthate            5733 non-null float64
# rougher.input.floatbank11_sulfate             5801 non-null float64
# rougher.input.floatbank11_xanthate            5503 non-null float64
# rougher.state.floatbank10_a_air               5839 non-null float64
# rougher.state.floatbank10_a_level             5840 non-null float64
# rougher.state.floatbank10_b_air               5839 non-null float64
# rougher.state.floatbank10_b_level             5840 non-null float64
# rougher.state.floatbank10_c_air               5839 non-null float64
# rougher.state.floatbank10_c_level             5840 non-null float64
# rougher.state.floatbank10_d_air               5839 non-null float64
# rougher.state.floatbank10_d_level             5840 non-null float64
# rougher.state.floatbank10_e_air               5839 non-null float64
# rougher.state.floatbank10_e_level             5840 non-null float64
# rougher.state.floatbank10_f_air               5839 non-null float64
# rougher.state.floatbank10_f_level             5840 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5836 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5840 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5833 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5840 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5822 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5840 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5840 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5840 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5840 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5840 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5840 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5840 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5840 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5840 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5840 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5840 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5840 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5840 non-null float64
# dtypes: float64(52), object(1)
# memory usage: 2.4+ MB

# %%
full = pd.read_csv('/datasets/gold_recovery_full.csv')
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22716 entries, 0 to 22715
# Data columns (total 87 columns):
# date                                                  22716 non-null object
# final.output.concentrate_ag                           22627 non-null float64
# final.output.concentrate_pb                           22629 non-null float64
# final.output.concentrate_sol                          22331 non-null float64
# final.output.concentrate_au                           22630 non-null float64
# final.output.recovery                                 20753 non-null float64
# final.output.tail_ag                                  22633 non-null float64
# final.output.tail_pb                                  22516 non-null float64
# final.output.tail_sol                                 22445 non-null float64
# final.output.tail_au                                  22635 non-null float64
# primary_cleaner.input.sulfate                         21107 non-null float64
# primary_cleaner.input.depressant                      21170 non-null float64
# primary_cleaner.input.feed_size                       22716 non-null float64
# primary_cleaner.input.xanthate                        21565 non-null float64
# primary_cleaner.output.concentrate_ag                 22618 non-null float64
# primary_cleaner.output.concentrate_pb                 22268 non-null float64
# primary_cleaner.output.concentrate_sol                21918 non-null float64
# primary_cleaner.output.concentrate_au                 22618 non-null float64
# primary_cleaner.output.tail_ag                        22614 non-null float64
# primary_cleaner.output.tail_pb                        22594 non-null float64
# primary_cleaner.output.tail_sol                       22365 non-null float64
# primary_cleaner.output.tail_au                        22617 non-null float64
# primary_cleaner.state.floatbank8_a_air                22660 non-null float64
# primary_cleaner.state.floatbank8_a_level              22667 non-null float64
# primary_cleaner.state.floatbank8_b_air                22660 non-null float64
# primary_cleaner.state.floatbank8_b_level              22673 non-null float64
# primary_cleaner.state.floatbank8_c_air                22662 non-null float64
# primary_cleaner.state.floatbank8_c_level              22673 non-null float64
# primary_cleaner.state.floatbank8_d_air                22661 non-null float64
# primary_cleaner.state.floatbank8_d_level              22673 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         22672 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    22672 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    22672 non-null float64
# rougher.calculation.au_pb_ratio                       21089 non-null float64
# rougher.input.feed_ag                                 22618 non-null float64
# rougher.input.feed_pb                                 22472 non-null float64
# rougher.input.feed_rate                               22163 non-null float64
# rougher.input.feed_size                               22277 non-null float64
# rougher.input.feed_sol                                22357 non-null float64
# rougher.input.feed_au                                 22617 non-null float64
# rougher.input.floatbank10_sulfate                     21415 non-null float64
# rougher.input.floatbank10_xanthate                    22247 non-null float64
# rougher.input.floatbank11_sulfate                     22038 non-null float64
# rougher.input.floatbank11_xanthate                    20459 non-null float64
# rougher.output.concentrate_ag                         22618 non-null float64
# rougher.output.concentrate_pb                         22618 non-null float64
# rougher.output.concentrate_sol                        22526 non-null float64
# rougher.output.concentrate_au                         22618 non-null float64
# rougher.output.recovery                               19597 non-null float64
# rougher.output.tail_ag                                19979 non-null float64
# rougher.output.tail_pb                                22618 non-null float64
# rougher.output.tail_sol                               19980 non-null float64
# rougher.output.tail_au                                19980 non-null float64
# rougher.state.floatbank10_a_air                       22646 non-null float64
# rougher.state.floatbank10_a_level                     22647 non-null float64
# rougher.state.floatbank10_b_air                       22646 non-null float64
# rougher.state.floatbank10_b_level                     22647 non-null float64
# rougher.state.floatbank10_c_air                       22646 non-null float64
# rougher.state.floatbank10_c_level                     22654 non-null float64
# rougher.state.floatbank10_d_air                       22641 non-null float64
# rougher.state.floatbank10_d_level                     22649 non-null float64
# rougher.state.floatbank10_e_air                       22096 non-null float64
# rougher.state.floatbank10_e_level                     22649 non-null float64
# rougher.state.floatbank10_f_air                       22641 non-null float64
# rougher.state.floatbank10_f_level                     22642 non-null float64
# secondary_cleaner.output.tail_ag                      22616 non-null float64
# secondary_cleaner.output.tail_pb                      22600 non-null float64
# secondary_cleaner.output.tail_sol                     20501 non-null float64
# secondary_cleaner.output.tail_au                      22618 non-null float64
# secondary_cleaner.state.floatbank2_a_air              22333 non-null float64
# secondary_cleaner.state.floatbank2_a_level            22591 non-null float64
# secondary_cleaner.state.floatbank2_b_air              22538 non-null float64
# secondary_cleaner.state.floatbank2_b_level            22588 non-null float64
# secondary_cleaner.state.floatbank3_a_air              22585 non-null float64
# secondary_cleaner.state.floatbank3_a_level            22587 non-null float64
# secondary_cleaner.state.floatbank3_b_air              22592 non-null float64
# secondary_cleaner.state.floatbank3_b_level            22590 non-null float64
# secondary_cleaner.state.floatbank4_a_air              22571 non-null float64
# secondary_cleaner.state.floatbank4_a_level            22587 non-null float64
# secondary_cleaner.state.floatbank4_b_air              22608 non-null float64
# secondary_cleaner.state.floatbank4_b_level            22607 non-null float64
# secondary_cleaner.state.floatbank5_a_air              22615 non-null float64
# secondary_cleaner.state.floatbank5_a_level            22615 non-null float64
# secondary_cleaner.state.floatbank5_b_air              22615 non-null float64
# secondary_cleaner.state.floatbank5_b_level            22616 non-null float64
# secondary_cleaner.state.floatbank6_a_air              22597 non-null float64
# secondary_cleaner.state.floatbank6_a_level            22615 non-null float64
# dtypes: float64(86), object(1)
# memory usage: 15.1+ MB

# %% [markdown]
# ## Выводы:
# 1. Представлено 3 датасета: обучающий, тестовый и полный.
# 2. В полном и обучающем наборах данных 87 параметров, в тестовом - 52.
# 3. Во всех столбцах кроме date имеются пропуски.

# %% [markdown]
# ### 1.2 Работа с пропусками

# %% [markdown]
# Проверим, совпадают ли пропуски в обучающей и тестовой выборке с полным датасетом

# %%
col_test = test.columns

# %%
col_train = train.columns

# %%
for col in col_test:
    sum_nan = train[col].isna().sum() + test[col].isna().sum()
    full_nan = full[col].isna().sum()
    difference = full_nan - sum_nan
print(difference.sum())
# Out:
# 0

# %% [markdown]
# - Количество пропусков совпадает, следовательно датасеты идентичны по пропускам

# %% [markdown]
# Посмотрим доли пропусков во всем датасете

# %%
print(full.isna().mean().sort_values(ascending=False))
# Out:
# rougher.output.recovery                     0.137304
# rougher.output.tail_ag                      0.120488
# rougher.output.tail_sol                     0.120444
# rougher.output.tail_au                      0.120444
# rougher.input.floatbank11_xanthate          0.099357
#                                               ...
# primary_cleaner.state.floatbank8_b_level    0.001893
# primary_cleaner.state.floatbank8_c_level    0.001893
# primary_cleaner.state.floatbank8_d_level    0.001893
# primary_cleaner.input.feed_size             0.000000
# date                                        0.000000
# Length: 87, dtype: float64

# %% [markdown]
# - максимальная доля пропусков не превышает 14%

# %% [markdown]
# Предположим, что суммарная концентрация всех веществ одной из стадий обработки должна равняться 100. Проверим:

# %%
sum = (
    full['final.output.concentrate_ag']
    + full['final.output.concentrate_pb']
    + full['final.output.concentrate_sol']
    + full['final.output.concentrate_au']
    + full['final.output.tail_ag']
    + full['final.output.tail_pb']
    + full['final.output.tail_sol']
    + full['final.output.tail_au']
)
sum.describe()
# Out:
# count    22034.000000
# mean        86.360731
# std         28.027858
# min          0.000000
# 25%         90.582012
# 50%         95.098590
# 75%         99.077724
# max        111.926638
# dtype: float64

# %% [markdown]
# - Предположение неверно. Заполнить пропуски, исходя из концентрации известных веществ невозможна.

# %% [markdown]
# Удалим пропуски в столбцах из тестовой выборки

# %%
full.dropna(subset = col_test, inplace = True)
train.dropna(subset = col_test, inplace = True)
test.dropna(subset = col_test, inplace = True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5383 entries, 0 to 5855
# Data columns (total 53 columns):
# date                                          5383 non-null object
# primary_cleaner.input.sulfate                 5383 non-null float64
# primary_cleaner.input.depressant              5383 non-null float64
# primary_cleaner.input.feed_size               5383 non-null float64
# primary_cleaner.input.xanthate                5383 non-null float64
# primary_cleaner.state.floatbank8_a_air        5383 non-null float64
# primary_cleaner.state.floatbank8_a_level      5383 non-null float64
# primary_cleaner.state.floatbank8_b_air        5383 non-null float64
# primary_cleaner.state.floatbank8_b_level      5383 non-null float64
# primary_cleaner.state.floatbank8_c_air        5383 non-null float64
# primary_cleaner.state.floatbank8_c_level      5383 non-null float64
# primary_cleaner.state.floatbank8_d_air        5383 non-null float64
# primary_cleaner.state.floatbank8_d_level      5383 non-null float64
# rougher.input.feed_ag                         5383 non-null float64
# rougher.input.feed_pb                         5383 non-null float64
# rougher.input.feed_rate                       5383 non-null float64
# rougher.input.feed_size                       5383 non-null float64
# rougher.input.feed_sol                        5383 non-null float64
# rougher.input.feed_au                         5383 non-null float64
# rougher.input.floatbank10_sulfate             5383 non-null float64
# rougher.input.floatbank10_xanthate            5383 non-null float64
# rougher.input.floatbank11_sulfate             5383 non-null float64
# rougher.input.floatbank11_xanthate            5383 non-null float64
# rougher.state.floatbank10_a_air               5383 non-null float64
# rougher.state.floatbank10_a_level             5383 non-null float64
# rougher.state.floatbank10_b_air               5383 non-null float64
# rougher.state.floatbank10_b_level             5383 non-null float64
# rougher.state.floatbank10_c_air               5383 non-null float64
# rougher.state.floatbank10_c_level             5383 non-null float64
# rougher.state.floatbank10_d_air               5383 non-null float64
# rougher.state.floatbank10_d_level             5383 non-null float64
# rougher.state.floatbank10_e_air               5383 non-null float64
# rougher.state.floatbank10_e_level             5383 non-null float64
# rougher.state.floatbank10_f_air               5383 non-null float64
# rougher.state.floatbank10_f_level             5383 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5383 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5383 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5383 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5383 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5383 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5383 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5383 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5383 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5383 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5383 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5383 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5383 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5383 non-null float64
# dtypes: float64(52), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# ### 1.3 Проверка целевых признаков

# %% [markdown]
# Проверим, что эффективность обогащения рассчитана правильно. Вычислим её на обучающей выборке для признака rougher.output.recovery. Найдем MAE между вашими расчётами и значением признака. Опишите выводы

# %% [markdown]
# Для проверки сформируем датасет без пропусков в расчетном столбце

# %%
train_nan = train
train_nan.dropna(subset = ['rougher.output.recovery'], inplace = True)

# %%
train_nan['rougher.output.tail_au'].sort_values()
# Out:
# 16788    0.020676
# 15848    0.024545
# 16789    0.031234
# 13093    0.031642
# 15836    0.050228
#            ...
# 2591     6.648954
# 8946     7.325192
# 2920     8.649598
# 2590     8.733552
# 5037     8.783082
# Name: rougher.output.tail_au, Length: 12767, dtype: float64

# %% [markdown]
# Создадим функцию для расчета эффективности обогащения и посчитаем MAE для рассчитанного значения:

# %%
def recovery_rougher(data):
    c = data['rougher.output.concentrate_au']
    f = data['rougher.input.feed_au']
    t = data['rougher.output.tail_au']
    if c > 0 and f > 0 and t > 0:
        rec = ((c * (f - t)) / (f * (c - t))) * 100
        return rec

# %%
train_nan['rougher.output.recovery_check'] = train_nan.apply(recovery_rougher, axis=1).fillna(0)

# %%
mean_absolute_error(train_nan['rougher.output.recovery'], train_nan['rougher.output.recovery_check'])
# Out:
# 9.520664632288798e-15

# %% [markdown]
# - MAE для расчетного значения rougher.output.recovery получилось примерно = 0, следовательно целевые признаки в датасетах посчитаны верно

# %% [markdown]
# ### 1.4 Анализ признаков, отсутствующих в тестовой выборке

# %% [markdown]
# Проанализируем признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
not_col = []
for col in col_train:
    if col not in col_test:
        not_col.append(col)

# %%
len(not_col)
# Out:
# 34

# %%
not_col
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.recovery',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_pb',
#  'rougher.output.tail_sol',
#  'rougher.output.tail_au',
#  'secondary_cleaner.output.tail_ag',
#  'secondary_cleaner.output.tail_pb',
#  'secondary_cleaner.output.tail_sol',
#  'secondary_cleaner.output.tail_au']

# %% [markdown]
# Недоступными признаками в тестовой выборке являются:
# 1. Целевые признаки - final.output.recovery, rougher.output.recovery
# 2. Параметры продукта после каждого этапа - содержание веществ в концентрате и хвостах
# 3. Расчетные характеристики флотации
# Тип данных - вещественный

# %% [markdown]
# ### 1.5 Изменение типов данных

# %% [markdown]
# Изменим тип данных в столбце date на datetime

# %%
full['date'] = pd.to_datetime(full['date'], format='%Y-%m-%d %H:%M:%S')
train['date'] = pd.to_datetime(train['date'], format='%Y-%m-%d %H:%M:%S')
test['date'] = pd.to_datetime(test['date'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ### 1.6 Работа с целевыми признаками

# %% [markdown]
# Заполним по возможности пропуски в целевом признаке rougher.output.recovery для полного датасета и для тренировочного расчетными значениями

# %%
full['rougher.output.recovery_check'] = full.apply(recovery_rougher, axis=1)

# %%
full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18905 entries, 0 to 22715
# Data columns (total 88 columns):
# date                                                  18905 non-null datetime64[ns]
# final.output.concentrate_ag                           18899 non-null float64
# final.output.concentrate_pb                           18901 non-null float64
# final.output.concentrate_sol                          18679 non-null float64
# final.output.concentrate_au                           18902 non-null float64
# final.output.recovery                                 18664 non-null float64
# final.output.tail_ag                                  18903 non-null float64
# final.output.tail_pb                                  18887 non-null float64
# final.output.tail_sol                                 18867 non-null float64
# final.output.tail_au                                  18905 non-null float64
# primary_cleaner.input.sulfate                         18905 non-null float64
# primary_cleaner.input.depressant                      18905 non-null float64
# primary_cleaner.input.feed_size                       18905 non-null float64
# primary_cleaner.input.xanthate                        18905 non-null float64
# primary_cleaner.output.concentrate_ag                 18905 non-null float64
# primary_cleaner.output.concentrate_pb                 18726 non-null float64
# primary_cleaner.output.concentrate_sol                18496 non-null float64
# primary_cleaner.output.concentrate_au                 18905 non-null float64
# primary_cleaner.output.tail_ag                        18901 non-null float64
# primary_cleaner.output.tail_pb                        18883 non-null float64
# primary_cleaner.output.tail_sol                       18769 non-null float64
# primary_cleaner.output.tail_au                        18905 non-null float64
# primary_cleaner.state.floatbank8_a_air                18905 non-null float64
# primary_cleaner.state.floatbank8_a_level              18905 non-null float64
# primary_cleaner.state.floatbank8_b_air                18905 non-null float64
# primary_cleaner.state.floatbank8_b_level              18905 non-null float64
# primary_cleaner.state.floatbank8_c_air                18905 non-null float64
# primary_cleaner.state.floatbank8_c_level              18905 non-null float64
# primary_cleaner.state.floatbank8_d_air                18905 non-null float64
# primary_cleaner.state.floatbank8_d_level              18905 non-null float64
# rougher.calculation.sulfate_to_au_concentrate         18905 non-null float64
# rougher.calculation.floatbank10_sulfate_to_au_feed    18905 non-null float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    18905 non-null float64
# rougher.calculation.au_pb_ratio                       18819 non-null float64
# rougher.input.feed_ag                                 18905 non-null float64
# rougher.input.feed_pb                                 18905 non-null float64
# rougher.input.feed_rate                               18905 non-null float64
# rougher.input.feed_size                               18905 non-null float64
# rougher.input.feed_sol                                18905 non-null float64
# rougher.input.feed_au                                 18905 non-null float64
# rougher.input.floatbank10_sulfate                     18905 non-null float64
# rougher.input.floatbank10_xanthate                    18905 non-null float64
# rougher.input.floatbank11_sulfate                     18905 non-null float64
# rougher.input.floatbank11_xanthate                    18905 non-null float64
# rougher.output.concentrate_ag                         18905 non-null float64
# rougher.output.concentrate_pb                         18905 non-null float64
# rougher.output.concentrate_sol                        18864 non-null float64
# rougher.output.concentrate_au                         18905 non-null float64
# rougher.output.recovery                               18012 non-null float64
# rougher.output.tail_ag                                18283 non-null float64
# rougher.output.tail_pb                                18905 non-null float64
# rougher.output.tail_sol                               18284 non-null float64
# rougher.output.tail_au                                18284 non-null float64
# rougher.state.floatbank10_a_air                       18905 non-null float64
# rougher.state.floatbank10_a_level                     18905 non-null float64
# rougher.state.floatbank10_b_air                       18905 non-null float64
# rougher.state.floatbank10_b_level                     18905 non-null float64
# rougher.state.floatbank10_c_air                       18905 non-null float64
# rougher.state.floatbank10_c_level                     18905 non-null float64
# rougher.state.floatbank10_d_air                       18905 non-null float64
# rougher.state.floatbank10_d_level                     18905 non-null float64
# rougher.state.floatbank10_e_air                       18905 non-null float64
# rougher.state.floatbank10_e_level                     18905 non-null float64
# rougher.state.floatbank10_f_air                       18905 non-null float64
# rougher.state.floatbank10_f_level                     18905 non-null float64
# secondary_cleaner.output.tail_ag                      18904 non-null float64
# secondary_cleaner.output.tail_pb                      18888 non-null float64
# secondary_cleaner.output.tail_sol                     17260 non-null float64
# secondary_cleaner.output.tail_au                      18905 non-null float64
# secondary_cleaner.state.floatbank2_a_air              18905 non-null float64
# secondary_cleaner.state.floatbank2_a_level            18905 non-null float64
# secondary_cleaner.state.floatbank2_b_air              18905 non-null float64
# secondary_cleaner.state.floatbank2_b_level            18905 non-null float64
# secondary_cleaner.state.floatbank3_a_air              18905 non-null float64
# secondary_cleaner.state.floatbank3_a_level            18905 non-null float64
# secondary_cleaner.state.floatbank3_b_air              18905 non-null float64
# secondary_cleaner.state.floatbank3_b_level            18905 non-null float64
# secondary_cleaner.state.floatbank4_a_air              18905 non-null float64
# secondary_cleaner.state.floatbank4_a_level            18905 non-null float64
# secondary_cleaner.state.floatbank4_b_air              18905 non-null float64
# secondary_cleaner.state.floatbank4_b_level            18905 non-null float64
# secondary_cleaner.state.floatbank5_a_air              18905 non-null float64
# secondary_cleaner.state.floatbank5_a_level            18905 non-null float64
# secondary_cleaner.state.floatbank5_b_air              18905 non-null float64
# secondary_cleaner.state.floatbank5_b_level            18905 non-null float64
# secondary_cleaner.state.floatbank6_a_air              18905 non-null float64
# secondary_cleaner.state.floatbank6_a_level            18905 non-null float64
# rougher.output.recovery_check                         17913 non-null float64
# dtypes: datetime64[ns](1), float64(87)
# memory usage: 12.8 MB

# %% [markdown]
# - В исходном датасете указано максимально возможное количество целевых признаков, поэтому заполнить пропуски не получится

# %% [markdown]
# Выделим целевые признаки в отдельный датасет

# %%
full_recovery = full[['date', 'final.output.recovery', 'rougher.output.recovery']]

# %% [markdown]
# Для проверки модели на тестовой выборке, добавим к ней целевые признаки из полного датасета

# %%
test = test.merge(full_recovery, on='date', how='left')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5383 entries, 0 to 5382
# Data columns (total 55 columns):
# date                                          5383 non-null datetime64[ns]
# primary_cleaner.input.sulfate                 5383 non-null float64
# primary_cleaner.input.depressant              5383 non-null float64
# primary_cleaner.input.feed_size               5383 non-null float64
# primary_cleaner.input.xanthate                5383 non-null float64
# primary_cleaner.state.floatbank8_a_air        5383 non-null float64
# primary_cleaner.state.floatbank8_a_level      5383 non-null float64
# primary_cleaner.state.floatbank8_b_air        5383 non-null float64
# primary_cleaner.state.floatbank8_b_level      5383 non-null float64
# primary_cleaner.state.floatbank8_c_air        5383 non-null float64
# primary_cleaner.state.floatbank8_c_level      5383 non-null float64
# primary_cleaner.state.floatbank8_d_air        5383 non-null float64
# primary_cleaner.state.floatbank8_d_level      5383 non-null float64
# rougher.input.feed_ag                         5383 non-null float64
# rougher.input.feed_pb                         5383 non-null float64
# rougher.input.feed_rate                       5383 non-null float64
# rougher.input.feed_size                       5383 non-null float64
# rougher.input.feed_sol                        5383 non-null float64
# rougher.input.feed_au                         5383 non-null float64
# rougher.input.floatbank10_sulfate             5383 non-null float64
# rougher.input.floatbank10_xanthate            5383 non-null float64
# rougher.input.floatbank11_sulfate             5383 non-null float64
# rougher.input.floatbank11_xanthate            5383 non-null float64
# rougher.state.floatbank10_a_air               5383 non-null float64
# rougher.state.floatbank10_a_level             5383 non-null float64
# rougher.state.floatbank10_b_air               5383 non-null float64
# rougher.state.floatbank10_b_level             5383 non-null float64
# rougher.state.floatbank10_c_air               5383 non-null float64
# rougher.state.floatbank10_c_level             5383 non-null float64
# rougher.state.floatbank10_d_air               5383 non-null float64
# rougher.state.floatbank10_d_level             5383 non-null float64
# rougher.state.floatbank10_e_air               5383 non-null float64
# rougher.state.floatbank10_e_level             5383 non-null float64
# rougher.state.floatbank10_f_air               5383 non-null float64
# rougher.state.floatbank10_f_level             5383 non-null float64
# secondary_cleaner.state.floatbank2_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank2_a_level    5383 non-null float64
# secondary_cleaner.state.floatbank2_b_air      5383 non-null float64
# secondary_cleaner.state.floatbank2_b_level    5383 non-null float64
# secondary_cleaner.state.floatbank3_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank3_a_level    5383 non-null float64
# secondary_cleaner.state.floatbank3_b_air      5383 non-null float64
# secondary_cleaner.state.floatbank3_b_level    5383 non-null float64
# secondary_cleaner.state.floatbank4_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank4_a_level    5383 non-null float64
# secondary_cleaner.state.floatbank4_b_air      5383 non-null float64
# secondary_cleaner.state.floatbank4_b_level    5383 non-null float64
# secondary_cleaner.state.floatbank5_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank5_a_level    5383 non-null float64
# secondary_cleaner.state.floatbank5_b_air      5383 non-null float64
# secondary_cleaner.state.floatbank5_b_level    5383 non-null float64
# secondary_cleaner.state.floatbank6_a_air      5383 non-null float64
# secondary_cleaner.state.floatbank6_a_level    5383 non-null float64
# final.output.recovery                         5333 non-null float64
# rougher.output.recovery                       5245 non-null float64
# dtypes: datetime64[ns](1), float64(54)
# memory usage: 2.3 MB

# %% [markdown]
# Удалим из датасетов пропуски в целевых признаках

# %%
full.dropna(subset = ['rougher.output.recovery', 'final.output.recovery'], inplace = True)
train.dropna(subset = ['rougher.output.recovery', 'final.output.recovery'], inplace = True)
test.dropna(subset = ['rougher.output.recovery', 'final.output.recovery'], inplace = True)

# %% [markdown]
# # 2. Анализ данных

# %% [markdown]
# ### 2.1 Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %% [markdown]
# 2.1.1 Концентрация Au

# %% [markdown]
# - Покажем распределение концентраций на общем графике

# %%
ax = full['rougher.output.concentrate_au'].plot(kind='hist', figsize=(15, 5), bins=100, grid=True, legend=True)
full['primary_cleaner.output.concentrate_au'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True)
full['final.output.concentrate_au'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True)
plt.show()

# %% [markdown]
# - Из графика видно, что концентрация золота увеличивается. Посчитаем на сколько увеличивается концентрация

# %%
print((full['primary_cleaner.output.concentrate_au'] - full['rougher.output.concentrate_au']).mean())
# Out:
# 12.234057141076471

# %%
print((full['final.output.concentrate_au'] - full['primary_cleaner.output.concentrate_au']).mean())
# Out:
# 12.03950239195873

# %% [markdown]
# После каждого этапа концентрация золота увеличивается в среднем на 12 %.

# %% [markdown]
# 2.1.2 Концентрация Ag

# %% [markdown]
# - Покажем распределение концентраций на общем графике

# %%
ax = full['rougher.output.concentrate_ag'].plot(kind='hist', figsize=(15, 5), bins=100, grid=True, legend=True)
full['primary_cleaner.output.concentrate_ag'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True)
full['final.output.concentrate_ag'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True)
plt.show()

# %% [markdown]
# - Из графика видно, что концентрация серебра увеличивается. Посчитаем на сколько уменьшается концентрация

# %%
print((full['primary_cleaner.output.concentrate_ag'] - full['rougher.output.concentrate_ag']).mean())
# Out:
# -3.518517294102368

# %%
print((full['final.output.concentrate_ag'] - full['primary_cleaner.output.concentrate_ag']).mean())
# Out:
# -3.348605492688304

# %% [markdown]
# После каждого этапа концентрация серебра уменьшается в среднем на 3 %.

# %% [markdown]
# 2.1.3 Концентрация Pb

# %% [markdown]
# - Покажем распределение концентраций на общем графике

# %%
ax = full['rougher.output.concentrate_pb'].plot(kind='hist', figsize=(15, 5), bins=100, grid=True, legend=True, alpha=0.7)
full['primary_cleaner.output.concentrate_pb'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True, alpha=0.7)
full['final.output.concentrate_pb'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True, alpha=0.7)
plt.show()

# %% [markdown]
# - Из графика видно, что концентрация свинца увеличивается после флотации, и не изменяется после очистки. Посчитаем на сколько изменяется концентрация

# %%
print((full['primary_cleaner.output.concentrate_pb'] - full['rougher.output.concentrate_pb']).mean())
# Out:
# 2.2258144404795406

# %%
print((full['final.output.concentrate_pb'] - full['primary_cleaner.output.concentrate_pb']).mean())
# Out:
# 0.15337759258918895

# %% [markdown]
# Концентрация свинца практически неизменна на всем протяжении очистки

# %% [markdown]
# ## Вывод:
# 1. Концентрация золота после каждого этапа обработки увеличивается в среднем на 12 %.
# 2. Концентрация серебра после каждого этапа обработки уменьшается в среднем на 3 %.
# 3. Концентрация свинца остается неизменной.

# %% [markdown]
# ### 2.2 Сравним распределения размеров гранул сырья на обучающей и тестовой выборках

# %%
fig, axes = plt.subplots(1, 2)
train['rougher.input.feed_size'].plot(kind='hist', 
                                      figsize=(15, 15), 
                                      ax=axes[0], 
                                      bins=100, 
                                      grid=True, 
                                      title='train',
                                      ylim=(0, 500))
test['rougher.input.feed_size'].plot(kind='hist', 
                                     figsize=(15, 15), 
                                     ax=axes[1], 
                                     bins=100, 
                                     grid=True, 
                                     title='train', 
                                     color='orange',
                                     ylim=(0, 500))

# %% [markdown]
# Основная доля размеров гранул находится в диапазоне от 40 до 80. Но есть размеры до 400. На первый взгляд распределение размеров гранул в обучающей и тестовой выборках идентичны. Проверим распределение методом describe()

# %%
train['rougher.input.feed_size'].describe()
# Out:
# count    12679.000000
# mean        58.414412
# std         20.441275
# min          9.659576
# 25%         48.721041
# 50%         54.651129
# 75%         63.719220
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64

# %%
test['rougher.input.feed_size'].describe()
# Out:
# count    5229.000000
# mean       55.863978
# std        18.914656
# min         0.046369
# 25%        43.911874
# 50%        50.772729
# 75%        62.265394
# max       392.494040
# Name: rougher.input.feed_size, dtype: float64

# %% [markdown]
# Здесь также не наблюдается различий

# %% [markdown]
# ### 2.3. Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %% [markdown]
# - Для сравнения обучающей и тестовой добавим в тестовую выборку данные с концентратами. Создадим новую выборку test_new

# %%
full_conc = full[['date', 'final.output.concentrate_ag', 
                  'final.output.concentrate_pb', 
                  'final.output.concentrate_sol', 
                  'final.output.concentrate_au',
                 'primary_cleaner.output.concentrate_ag',
                  'primary_cleaner.output.concentrate_pb',
                  'primary_cleaner.output.concentrate_sol',
                  'primary_cleaner.output.concentrate_au',
                 'rougher.output.concentrate_ag',
                  'rougher.output.concentrate_pb', 
                  'rougher.output.concentrate_sol',
                  'rougher.output.concentrate_au']]

# %%
test_new = test
test_new = test_new.merge(full_conc, on='date', how='left')

# %% [markdown]
# - Добавим в обучающую и тестовую выборки столбцы с суммарными концентрациями веществ на 3-х этапах

# %%
final_output_conc = ['final.output.concentrate_ag', 
                  'final.output.concentrate_pb', 
                  'final.output.concentrate_sol', 
                  'final.output.concentrate_au']

# %%
primary_output_conc = ['primary_cleaner.output.concentrate_ag',
                  'primary_cleaner.output.concentrate_pb',
                  'primary_cleaner.output.concentrate_sol',
                  'primary_cleaner.output.concentrate_au']

# %%
rougher_output_conc = ['rougher.output.concentrate_ag',
                  'rougher.output.concentrate_pb', 
                  'rougher.output.concentrate_sol',
                  'rougher.output.concentrate_au']

# %%
train['final_output_conc'] = train[final_output_conc].sum(axis=1)
train['primary_output_conc'] = train[primary_output_conc].sum(axis=1)
train['rougher_output_conc'] = train[rougher_output_conc].sum(axis=1)

# %%
test_new['final_output_conc'] = test_new[final_output_conc].sum(axis=1)
test_new['primary_output_conc'] = test_new[primary_output_conc].sum(axis=1)
test_new['rougher_output_conc'] = test_new[rougher_output_conc].sum(axis=1)

# %% [markdown]
# - Сравним распределения

# %%
ax = train['final_output_conc'].plot(kind='hist', figsize=(15, 5), bins=100, grid=True, legend=True, alpha=0.7)
train['primary_output_conc'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True, alpha=0.7)
train['rougher_output_conc'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True, alpha=0.7)
plt.show()

# %%
print(train['final_output_conc'].describe()) 
print(train['primary_output_conc'].describe())
print(train['rougher_output_conc'].describe())
# Out:
# count    12679.000000
# mean        68.577864
# std          6.420817
# min          0.000000
# 25%         67.593534
# 50%         69.188719
# 75%         71.050394
# max         80.210644
# Name: final_output_conc, dtype: float64
# count    12679.000000
# mean        60.262440
# std          9.880960
# min          0.000000
# 25%         58.113840
# 50%         61.770054
# 75%         65.283791
# max         76.918076
# Name: primary_output_conc, dtype: float64
# count    12679.000000
# mean        67.582614
# std         11.888300
# min          0.000000
# 25%         65.155435
# 50%         69.259055
# 75%         73.486943
# max         87.273435
# Name: rougher_output_conc, dtype: float64

# %%
ax = test_new['final_output_conc'].plot(kind='hist', figsize=(15, 5), bins=100, grid=True, legend=True, alpha=0.7)
test_new['primary_output_conc'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True, alpha=0.7)
test_new['rougher_output_conc'].plot(kind='hist', figsize=(15, 5), ax=ax, bins=100, grid=True, legend=True, alpha=0.7)
plt.show()

# %%
print(test_new['final_output_conc'].describe()) 
print(test_new['primary_output_conc'].describe())
print(test_new['rougher_output_conc'].describe())
# Out:
# count    5229.000000
# mean       69.615526
# std         7.473195
# min         0.000000
# 25%        69.363400
# 50%        70.709281
# 75%        72.084634
# max        79.977670
# Name: final_output_conc, dtype: float64
# count    5229.000000
# mean       62.340702
# std         8.510653
# min         0.000000
# 25%        61.225854
# 50%        64.145931
# 75%        66.123232
# max        80.749343
# Name: primary_output_conc, dtype: float64
# count    5229.000000
# mean       70.827765
# std        11.419470
# min         0.000000
# 25%        69.230682
# 50%        72.667060
# 75%        75.801135
# max        86.393020
# Name: rougher_output_conc, dtype: float64

# %% [markdown]
# В суммарных концентрациях наблюдаются выбросы - от 40 и до 0. Удалим данные выбросы из обучающей выборке, чтобы они не влияли на модель

# %%
train = train[(train['final_output_conc'] != 0) & (train['final.output.recovery'] != 0)]

# %%
train.shape
# Out:
# (12643, 91)

# %% [markdown]
# ## Вывод:
# 1. Распределения в тестовой и обучающих выборках аналогичны, различий не наблюдается.
# 2. В распределениях наблюдаются аномалии(выбросы)
# 3. Данные выбросы удалены из обучающей выборки

# %% [markdown]
# # 3. Построение моделей

# %% [markdown]
# ### 3.1. Напишем функцию для вычисления sMAPE. Сделаем ее метрикой для дальнейших операций

# %%
def smape(target, pred):
    x = (abs(target - pred) / ((abs(target) + abs(pred)) / 2)) * 100
    smape = x.sum() / len(target)
    return smape

# %%
my_scorer = make_scorer(smape)

# %% [markdown]
# ### 3.2. Обучим разные модели и оценим их качество кросс-валидацией

# %% [markdown]
# 3.2.1 Посмотрим на корреляцию признаков по отношению к целевым

# %%
corr = train[test.columns].corr()
corr
# Out:
#                                             primary_cleaner.input.sulfate  \
# primary_cleaner.input.sulfate                                    1.000000
# primary_cleaner.input.depressant                                 0.419215
# primary_cleaner.input.feed_size                                  0.116000
# primary_cleaner.input.xanthate                                   0.210617
# primary_cleaner.state.floatbank8_a_air                           0.064572
# primary_cleaner.state.floatbank8_a_level                        -0.062365
# primary_cleaner.state.floatbank8_b_air                           0.077407
# primary_cleaner.state.floatbank8_b_level                        -0.056037
# primary_cleaner.state.floatbank8_c_air                           0.080308
# primary_cleaner.state.floatbank8_c_level                        -0.051234
# primary_cleaner.state.floatbank8_d_air                           0.143102
# primary_cleaner.state.floatbank8_d_level                        -0.057319
# rougher.input.feed_ag                                            0.570459
# rougher.input.feed_pb                                            0.593338
# rougher.input.feed_rate                                          0.202263
# rougher.input.feed_size                                          0.024802
# rougher.input.feed_sol                                           0.344133
# rougher.input.feed_au                                            0.652727
# rougher.input.floatbank10_sulfate                                0.384562
# rougher.input.floatbank10_xanthate                               0.325940
# rougher.input.floatbank11_sulfate                                0.396539
# rougher.input.floatbank11_xanthate                               0.324226
# rougher.state.floatbank10_a_air                                  0.248435
# rougher.state.floatbank10_a_level                                0.121582
# rougher.state.floatbank10_b_air                                 -0.169685
# rougher.state.floatbank10_b_level                               -0.137651
# rougher.state.floatbank10_c_air                                 -0.213046
# rougher.state.floatbank10_c_level                               -0.136137
# rougher.state.floatbank10_d_air                                 -0.250549
# rougher.state.floatbank10_d_level                               -0.133134
# rougher.state.floatbank10_e_air                                 -0.222120
# rougher.state.floatbank10_e_level                               -0.143647
# rougher.state.floatbank10_f_air                                 -0.182535
# rougher.state.floatbank10_f_level                               -0.141997
# secondary_cleaner.state.floatbank2_a_air                         0.095216
# secondary_cleaner.state.floatbank2_a_level                      -0.010634
# secondary_cleaner.state.floatbank2_b_air                         0.109293
# secondary_cleaner.state.floatbank2_b_level                       0.003514
# secondary_cleaner.state.floatbank3_a_air                         0.130929
# secondary_cleaner.state.floatbank3_a_level                       0.020720
# secondary_cleaner.state.floatbank3_b_air                         0.039972
# secondary_cleaner.state.floatbank3_b_level                      -0.061249
# secondary_cleaner.state.floatbank4_a_air                         0.159382
# secondary_cleaner.state.floatbank4_a_level                       0.075967
# secondary_cleaner.state.floatbank4_b_air                         0.183535
# secondary_cleaner.state.floatbank4_b_level                      -0.034971
# secondary_cleaner.state.floatbank5_a_air                         0.065506
# secondary_cleaner.state.floatbank5_a_level                      -0.016453
# secondary_cleaner.state.floatbank5_b_air                         0.076318
# secondary_cleaner.state.floatbank5_b_level                      -0.003665
# secondary_cleaner.state.floatbank6_a_air                        -0.062265
# secondary_cleaner.state.floatbank6_a_level                      -0.157876
# final.output.recovery                                            0.399741
# rougher.output.recovery                                          0.304197
#
#                                             primary_cleaner.input.depressant  \
# primary_cleaner.input.sulfate                                       0.419215
# primary_cleaner.input.depressant                                    1.000000
# primary_cleaner.input.feed_size                                     0.141392
# primary_cleaner.input.xanthate                                      0.271772
# primary_cleaner.state.floatbank8_a_air                             -0.121580
# primary_cleaner.state.floatbank8_a_level                            0.102337
# primary_cleaner.state.floatbank8_b_air                             -0.090787
# primary_cleaner.state.floatbank8_b_level                            0.120310
# primary_cleaner.state.floatbank8_c_air                             -0.102834
# primary_cleaner.state.floatbank8_c_level                            0.124164
# primary_cleaner.state.floatbank8_d_air                             -0.072089
# primary_cleaner.state.floatbank8_d_level                            0.037642
# rougher.input.feed_ag                                               0.492159
# rougher.input.feed_pb                                               0.275512
# rougher.input.feed_rate                                             0.052218
# rougher.input.feed_size                                             0.006765
# rougher.input.feed_sol                                              0.037859
# rougher.input.feed_au                                               0.441162
# rougher.input.floatbank10_sulfate                                   0.141161
# rougher.input.floatbank10_xanthate                                  0.335371
# rougher.input.floatbank11_sulfate                                   0.150886
# rougher.input.floatbank11_xanthate                                  0.357251
# rougher.state.floatbank10_a_air                                    -0.017124
# rougher.state.floatbank10_a_level                                  -0.252630
# rougher.state.floatbank10_b_air                                    -0.074422
# rougher.state.floatbank10_b_level                                  -0.274850
# rougher.state.floatbank10_c_air                                    -0.118077
# rougher.state.floatbank10_c_level                                  -0.269894
# rougher.state.floatbank10_d_air                                    -0.095795
# rougher.state.floatbank10_d_level                                  -0.268977
# rougher.state.floatbank10_e_air                                     0.010571
# rougher.state.floatbank10_e_level                                  -0.277466
# rougher.state.floatbank10_f_air                                    -0.015105
# rougher.state.floatbank10_f_level                                  -0.281396
# secondary_cleaner.state.floatbank2_a_air                           -0.125228
# secondary_cleaner.state.floatbank2_a_level                          0.113323
# secondary_cleaner.state.floatbank2_b_air                            0.037059
# secondary_cleaner.state.floatbank2_b_level                          0.091858
# secondary_cleaner.state.floatbank3_a_air                           -0.164841
# secondary_cleaner.state.floatbank3_a_level                         -0.066189
# secondary_cleaner.state.floatbank3_b_air                            0.031155
# secondary_cleaner.state.floatbank3_b_level                         -0.003322
# secondary_cleaner.state.floatbank4_a_air                           -0.219649
# secondary_cleaner.state.floatbank4_a_level                         -0.155725
# secondary_cleaner.state.floatbank4_b_air                           -0.114314
# secondary_cleaner.state.floatbank4_b_level                         -0.273682
# secondary_cleaner.state.floatbank5_a_air                           -0.245509
# secondary_cleaner.state.floatbank5_a_level                         -0.163676
# secondary_cleaner.state.floatbank5_b_air                           -0.201854
# secondary_cleaner.state.floatbank5_b_level                         -0.154124
# secondary_cleaner.state.floatbank6_a_air                           -0.159950
# secondary_cleaner.state.floatbank6_a_level                         -0.127655
# final.output.recovery                                               0.144982
# rougher.output.recovery                                             0.025652
#
#                                             primary_cleaner.input.feed_size  \
# primary_cleaner.input.sulfate                                      0.116000
# primary_cleaner.input.depressant                                   0.141392
# primary_cleaner.input.feed_size                                    1.000000
# primary_cleaner.input.xanthate                                    -0.028851
# primary_cleaner.state.floatbank8_a_air                            -0.109961
# primary_cleaner.state.floatbank8_a_level                           0.068071
# primary_cleaner.state.floatbank8_b_air                            -0.112652
# primary_cleaner.state.floatbank8_b_level                           0.070284
# primary_cleaner.state.floatbank8_c_air                            -0.129807
# primary_cleaner.state.floatbank8_c_level                           0.068863
# primary_cleaner.state.floatbank8_d_air                            -0.178453
# primary_cleaner.state.floatbank8_d_level                           0.064950
# rougher.input.feed_ag                                              0.106310
# rougher.input.feed_pb                                             -0.125949
# rougher.input.feed_rate                                            0.022286
# rougher.input.feed_size                                           -0.113215
# rougher.input.feed_sol                                             0.026949
# rougher.input.feed_au                                              0.114445
# rougher.input.floatbank10_sulfate                                  0.069839
# rougher.input.floatbank10_xanthate                                -0.025728
# rougher.input.floatbank11_sulfate                                  0.076923
# rougher.input.floatbank11_xanthate                                -0.010690
# rougher.state.floatbank10_a_air                                   -0.216231
# rougher.state.floatbank10_a_level                                 -0.346342
# rougher.state.floatbank10_b_air                                    0.245910
# rougher.state.floatbank10_b_level                                  0.145194
# rougher.state.floatbank10_c_air                                    0.250125
# rougher.state.floatbank10_c_level                                  0.136871
# rougher.state.floatbank10_d_air                                    0.253819
# rougher.state.floatbank10_d_level                                  0.137364
# rougher.state.floatbank10_e_air                                    0.197729
# rougher.state.floatbank10_e_level                                  0.130610
# rougher.state.floatbank10_f_air                                    0.200554
# rougher.state.floatbank10_f_level                                  0.132143
# secondary_cleaner.state.floatbank2_a_air                          -0.200757
# secondary_cleaner.state.floatbank2_a_level                         0.080776
# secondary_cleaner.state.floatbank2_b_air                          -0.130390
# secondary_cleaner.state.floatbank2_b_level                         0.058335
# secondary_cleaner.state.floatbank3_a_air                          -0.122772
# secondary_cleaner.state.floatbank3_a_level                         0.134023
# secondary_cleaner.state.floatbank3_b_air                           0.063470
# secondary_cleaner.state.floatbank3_b_level                         0.140057
# secondary_cleaner.state.floatbank4_a_air                          -0.309792
# secondary_cleaner.state.floatbank4_a_level                         0.157659
# secondary_cleaner.state.floatbank4_b_air                          -0.220897
# secondary_cleaner.state.floatbank4_b_level                         0.054370
# secondary_cleaner.state.floatbank5_a_air                          -0.208005
# secondary_cleaner.state.floatbank5_a_level                         0.153177
# secondary_cleaner.state.floatbank5_b_air                          -0.178201
# secondary_cleaner.state.floatbank5_b_level                         0.155168
# secondary_cleaner.state.floatbank6_a_air                           0.187983
# secondary_cleaner.state.floatbank6_a_level                         0.067740
# final.output.recovery                                              0.040477
# rougher.output.recovery                                           -0.010591
#
#                                             primary_cleaner.input.xanthate  \
# primary_cleaner.input.sulfate                                     0.210617
# primary_cleaner.input.depressant                                  0.271772
# primary_cleaner.input.feed_size                                  -0.028851
# primary_cleaner.input.xanthate                                    1.000000
# primary_cleaner.state.floatbank8_a_air                            0.066277
# primary_cleaner.state.floatbank8_a_level                          0.021599
# primary_cleaner.state.floatbank8_b_air                            0.085254
# primary_cleaner.state.floatbank8_b_level                          0.018459
# primary_cleaner.state.floatbank8_c_air                            0.058347
# primary_cleaner.state.floatbank8_c_level                          0.015395
# primary_cleaner.state.floatbank8_d_air                            0.112211
# primary_cleaner.state.floatbank8_d_level                         -0.039818
# rougher.input.feed_ag                                             0.247160
# rougher.input.feed_pb                                            -0.017233
# rougher.input.feed_rate                                           0.226394
# rougher.input.feed_size                                           0.102677
# rougher.input.feed_sol                                            0.146465
# rougher.input.feed_au                                             0.144803
# rougher.input.floatbank10_sulfate                                -0.137380
# rougher.input.floatbank10_xanthate                                0.352774
# rougher.input.floatbank11_sulfate                                -0.126979
# rougher.input.floatbank11_xanthate                                0.362094
# rougher.state.floatbank10_a_air                                   0.107590
# rougher.state.floatbank10_a_level                                -0.068354
# rougher.state.floatbank10_b_air                                  -0.209307
# rougher.state.floatbank10_b_level                                -0.302634
# rougher.state.floatbank10_c_air                                  -0.240372
# rougher.state.floatbank10_c_level                                -0.313842
# rougher.state.floatbank10_d_air                                  -0.180212
# rougher.state.floatbank10_d_level                                -0.309657
# rougher.state.floatbank10_e_air                                  -0.049517
# rougher.state.floatbank10_e_level                                -0.307036
# rougher.state.floatbank10_f_air                                  -0.047207
# rougher.state.floatbank10_f_level                                -0.299988
# secondary_cleaner.state.floatbank2_a_air                         -0.121053
# secondary_cleaner.state.floatbank2_a_level                       -0.155298
# secondary_cleaner.state.floatbank2_b_air                         -0.040329
# secondary_cleaner.state.floatbank2_b_level                       -0.171268
# secondary_cleaner.state.floatbank3_a_air                          0.030647
# secondary_cleaner.state.floatbank3_a_level                       -0.254519
# secondary_cleaner.state.floatbank3_b_air                         -0.065625
# secondary_cleaner.state.floatbank3_b_level                       -0.119591
# secondary_cleaner.state.floatbank4_a_air                          0.053144
# secondary_cleaner.state.floatbank4_a_level                       -0.219813
# secondary_cleaner.state.floatbank4_b_air                          0.030759
# secondary_cleaner.state.floatbank4_b_level                       -0.314836
# secondary_cleaner.state.floatbank5_a_air                         -0.044373
# secondary_cleaner.state.floatbank5_a_level                       -0.205775
# secondary_cleaner.state.floatbank5_b_air                         -0.064958
# secondary_cleaner.state.floatbank5_b_level                       -0.200447
# secondary_cleaner.state.floatbank6_a_air                         -0.204229
# secondary_cleaner.state.floatbank6_a_level                       -0.086638
# final.output.recovery                                             0.189955
# rougher.output.recovery                                           0.103295
#
#                                             primary_cleaner.state.floatbank8_a_air  \
# primary_cleaner.input.sulfate                                             0.064572
# primary_cleaner.input.depressant                                         -0.121580
# primary_cleaner.input.feed_size                                          -0.109961
# primary_cleaner.input.xanthate                                            0.066277
# primary_cleaner.state.floatbank8_a_air                                    1.000000
# primary_cleaner.state.floatbank8_a_level                                  0.168028
# primary_cleaner.state.floatbank8_b_air                                    0.945555
# primary_cleaner.state.floatbank8_b_level                                  0.178727
# primary_cleaner.state.floatbank8_c_air                                    0.932321
# primary_cleaner.state.floatbank8_c_level                                  0.175949
# primary_cleaner.state.floatbank8_d_air                                    0.302439
# primary_cleaner.state.floatbank8_d_level                                  0.078037
# rougher.input.feed_ag                                                     0.185723
# rougher.input.feed_pb                                                     0.037836
# rougher.input.feed_rate                                                  -0.078265
# rougher.input.feed_size                                                   0.040751
# rougher.input.feed_sol                                                    0.081520
# rougher.input.feed_au                                                     0.108747
# rougher.input.floatbank10_sulfate                                        -0.054374
# rougher.input.floatbank10_xanthate                                       -0.018829
# rougher.input.floatbank11_sulfate                                        -0.059502
# rougher.input.floatbank11_xanthate                                       -0.041422
# rougher.state.floatbank10_a_air                                           0.392044
# rougher.state.floatbank10_a_level                                         0.240581
# rougher.state.floatbank10_b_air                                           0.179754
# rougher.state.floatbank10_b_level                                         0.354881
# rougher.state.floatbank10_c_air                                           0.139565
# rougher.state.floatbank10_c_level                                         0.347891
# rougher.state.floatbank10_d_air                                           0.151673
# rougher.state.floatbank10_d_level                                         0.346566
# rougher.state.floatbank10_e_air                                           0.198584
# rougher.state.floatbank10_e_level                                         0.355411
# rougher.state.floatbank10_f_air                                           0.209055
# rougher.state.floatbank10_f_level                                         0.353203
# secondary_cleaner.state.floatbank2_a_air                                  0.311132
# secondary_cleaner.state.floatbank2_a_level                               -0.011898
# secondary_cleaner.state.floatbank2_b_air                                  0.269669
# secondary_cleaner.state.floatbank2_b_level                                0.022248
# secondary_cleaner.state.floatbank3_a_air                                  0.457268
# secondary_cleaner.state.floatbank3_a_level                                0.293779
# secondary_cleaner.state.floatbank3_b_air                                  0.313024
# secondary_cleaner.state.floatbank3_b_level                                0.054097
# secondary_cleaner.state.floatbank4_a_air                                  0.544975
# secondary_cleaner.state.floatbank4_a_level                                0.320815
# secondary_cleaner.state.floatbank4_b_air                                  0.512701
# secondary_cleaner.state.floatbank4_b_level                                0.219003
# secondary_cleaner.state.floatbank5_a_air                                  0.554075
# secondary_cleaner.state.floatbank5_a_level                                0.255659
# secondary_cleaner.state.floatbank5_b_air                                  0.495113
# secondary_cleaner.state.floatbank5_b_level                                0.247407
# secondary_cleaner.state.floatbank6_a_air                                  0.303456
# secondary_cleaner.state.floatbank6_a_level                                0.053628
# final.output.recovery                                                     0.183474
# rougher.output.recovery                                                   0.096616
#
#                                             primary_cleaner.state.floatbank8_a_level  \
# primary_cleaner.input.sulfate                                              -0.062365
# primary_cleaner.input.depressant                                            0.102337
# primary_cleaner.input.feed_size                                             0.068071
# primary_cleaner.input.xanthate                                              0.021599
# primary_cleaner.state.floatbank8_a_air                                      0.168028
# primary_cleaner.state.floatbank8_a_level                                    1.000000
# primary_cleaner.state.floatbank8_b_air                                      0.122500
# primary_cleaner.state.floatbank8_b_level                                    0.977853
# primary_cleaner.state.floatbank8_c_air                                      0.156841
# primary_cleaner.state.floatbank8_c_level                                    0.964250
# primary_cleaner.state.floatbank8_d_air                                     -0.411705
# primary_cleaner.state.floatbank8_d_level                                    0.741842
# rougher.input.feed_ag                                                       0.001912
# rougher.input.feed_pb                                                      -0.048836
# rougher.input.feed_rate                                                     0.031101
# rougher.input.feed_size                                                    -0.005432
# rougher.input.feed_sol                                                     -0.143146
# rougher.input.feed_au                                                      -0.067516
# rougher.input.floatbank10_sulfate                                          -0.177780
# rougher.input.floatbank10_xanthate                                          0.228657
# rougher.input.floatbank11_sulfate                                          -0.173146
# rougher.input.floatbank11_xanthate                                          0.217629
# rougher.state.floatbank10_a_air                                            -0.023090
# rougher.state.floatbank10_a_level                                          -0.178256
# rougher.state.floatbank10_b_air                                             0.218562
# rougher.state.floatbank10_b_level                                          -0.072898
# rougher.state.floatbank10_c_air                                             0.172569
# rougher.state.floatbank10_c_level                                          -0.098154
# rougher.state.floatbank10_d_air                                             0.261275
# rougher.state.floatbank10_d_level                                          -0.100902
# rougher.state.floatbank10_e_air                                             0.291559
# rougher.state.floatbank10_e_level                                          -0.089405
# rougher.state.floatbank10_f_air                                             0.338737
# rougher.state.floatbank10_f_level                                          -0.098291
# secondary_cleaner.state.floatbank2_a_air                                    0.163613
# secondary_cleaner.state.floatbank2_a_level                                  0.201172
# secondary_cleaner.state.floatbank2_b_air                                    0.233796
# secondary_cleaner.state.floatbank2_b_level                                  0.183017
# secondary_cleaner.state.floatbank3_a_air                                    0.015363
# secondary_cleaner.state.floatbank3_a_level                                  0.079409
# secondary_cleaner.state.floatbank3_b_air                                    0.235238
# secondary_cleaner.state.floatbank3_b_level                                  0.169633
# secondary_cleaner.state.floatbank4_a_air                                   -0.025850
# secondary_cleaner.state.floatbank4_a_level                                  0.057816
# secondary_cleaner.state.floatbank4_b_air                                    0.112303
# secondary_cleaner.state.floatbank4_b_level                                 -0.043795
# secondary_cleaner.state.floatbank5_a_air                                    0.017703
# secondary_cleaner.state.floatbank5_a_level                                  0.108630
# secondary_cleaner.state.floatbank5_b_air                                    0.082875
# secondary_cleaner.state.floatbank5_b_level                                  0.082189
# secondary_cleaner.state.floatbank6_a_air                                    0.182385
# secondary_cleaner.state.floatbank6_a_level                                  0.196568
# final.output.recovery                                                       0.066636
# rougher.output.recovery                                                     0.049533
#
#                                             primary_cleaner.state.floatbank8_b_air  \
# primary_cleaner.input.sulfate                                             0.077407
# primary_cleaner.input.depressant                                         -0.090787
# primary_cleaner.input.feed_size                                          -0.112652
# primary_cleaner.input.xanthate                                            0.085254
# primary_cleaner.state.floatbank8_a_air                                    0.945555
# primary_cleaner.state.floatbank8_a_level                                  0.122500
# primary_cleaner.state.floatbank8_b_air                                    1.000000
# primary_cleaner.state.floatbank8_b_level                                  0.149161
# primary_cleaner.state.floatbank8_c_air                                    0.943508
# primary_cleaner.state.floatbank8_c_level                                  0.147364
# primary_cleaner.state.floatbank8_d_air                                    0.312372
# primary_cleaner.state.floatbank8_d_level                                  0.049889
# rougher.input.feed_ag                                                     0.215900
# rougher.input.feed_pb                                                     0.048059
# rougher.input.feed_rate                                                  -0.089862
# rougher.input.feed_size                                                   0.017938
# rougher.input.feed_sol                                                    0.067643
# rougher.input.feed_au                                                     0.137279
# rougher.input.floatbank10_sulfate                                        -0.069097
# rougher.input.floatbank10_xanthate                                        0.011107
# rougher.input.floatbank11_sulfate                                        -0.069107
# rougher.input.floatbank11_xanthate                                       -0.007198
# rougher.state.floatbank10_a_air                                           0.436068
# rougher.state.floatbank10_a_level                                         0.239410
# rougher.state.floatbank10_b_air                                           0.175526
# rougher.state.floatbank10_b_level                                         0.343299
# rougher.state.floatbank10_c_air                                           0.126316
# rougher.state.floatbank10_c_level                                         0.331566
# rougher.state.floatbank10_d_air                                           0.137202
# rougher.state.floatbank10_d_level                                         0.330297
# rougher.state.floatbank10_e_air                                           0.194432
# rougher.state.floatbank10_e_level                                         0.338959
# rougher.state.floatbank10_f_air                                           0.204412
# rougher.state.floatbank10_f_level                                         0.340913
# secondary_cleaner.state.floatbank2_a_air                                  0.254642
# secondary_cleaner.state.floatbank2_a_level                               -0.045526
# secondary_cleaner.state.floatbank2_b_air                                  0.233860
# secondary_cleaner.state.floatbank2_b_level                               -0.008194
# secondary_cleaner.state.floatbank3_a_air                                  0.434773
# secondary_cleaner.state.floatbank3_a_level                                0.303372
# secondary_cleaner.state.floatbank3_b_air                                  0.281693
# secondary_cleaner.state.floatbank3_b_level                                0.050138
# secondary_cleaner.state.floatbank4_a_air                                  0.530570
# secondary_cleaner.state.floatbank4_a_level                                0.332318
# secondary_cleaner.state.floatbank4_b_air                                  0.512121
# secondary_cleaner.state.floatbank4_b_level                                0.200492
# secondary_cleaner.state.floatbank5_a_air                                  0.558305
# secondary_cleaner.state.floatbank5_a_level                                0.260066
# secondary_cleaner.state.floatbank5_b_air                                  0.484098
# secondary_cleaner.state.floatbank5_b_level                                0.251952
# secondary_cleaner.state.floatbank6_a_air                                  0.302197
# secondary_cleaner.state.floatbank6_a_level                                0.032760
# final.output.recovery                                                     0.194162
# rougher.output.recovery                                                   0.107642
#
#                                             primary_cleaner.state.floatbank8_b_level  \
# primary_cleaner.input.sulfate                                              -0.056037
# primary_cleaner.input.depressant                                            0.120310
# primary_cleaner.input.feed_size                                             0.070284
# primary_cleaner.input.xanthate                                              0.018459
# primary_cleaner.state.floatbank8_a_air                                      0.178727
# primary_cleaner.state.floatbank8_a_level                                    0.977853
# primary_cleaner.state.floatbank8_b_air                                      0.149161
# primary_cleaner.state.floatbank8_b_level                                    1.000000
# primary_cleaner.state.floatbank8_c_air                                      0.168210
# primary_cleaner.state.floatbank8_c_level                                    0.969770
# primary_cleaner.state.floatbank8_d_air                                     -0.431277
# primary_cleaner.state.floatbank8_d_level                                    0.741665
# rougher.input.feed_ag                                                       0.019611
# rougher.input.feed_pb                                                      -0.049604
# rougher.input.feed_rate                                                     0.025167
# rougher.input.feed_size                                                    -0.015285
# rougher.input.feed_sol                                                     -0.160926
# rougher.input.feed_au                                                      -0.053384
# rougher.input.floatbank10_sulfate                                          -0.166158
# rougher.input.floatbank10_xanthate                                          0.235235
# rougher.input.floatbank11_sulfate                                          -0.161819
# rougher.input.floatbank11_xanthate                                          0.223220
# rougher.state.floatbank10_a_air                                            -0.032041
# rougher.state.floatbank10_a_level                                          -0.196291
# rougher.state.floatbank10_b_air                                             0.236523
# rougher.state.floatbank10_b_level                                          -0.062893
# rougher.state.floatbank10_c_air                                             0.186502
# rougher.state.floatbank10_c_level                                          -0.089043
# rougher.state.floatbank10_d_air                                             0.278911
# rougher.state.floatbank10_d_level                                          -0.092275
# rougher.state.floatbank10_e_air                                             0.306872
# rougher.state.floatbank10_e_level                                          -0.079946
# rougher.state.floatbank10_f_air                                             0.352686
# rougher.state.floatbank10_f_level                                          -0.089069
# secondary_cleaner.state.floatbank2_a_air                                    0.148321
# secondary_cleaner.state.floatbank2_a_level                                  0.209981
# secondary_cleaner.state.floatbank2_b_air                                    0.227106
# secondary_cleaner.state.floatbank2_b_level                                  0.191260
# secondary_cleaner.state.floatbank3_a_air                                   -0.005277
# secondary_cleaner.state.floatbank3_a_level                                  0.091341
# secondary_cleaner.state.floatbank3_b_air                                    0.225193
# secondary_cleaner.state.floatbank3_b_level                                  0.184076
# secondary_cleaner.state.floatbank4_a_air                                   -0.050936
# secondary_cleaner.state.floatbank4_a_level                                  0.069846
# secondary_cleaner.state.floatbank4_b_air                                    0.097478
# secondary_cleaner.state.floatbank4_b_level                                 -0.033107
# secondary_cleaner.state.floatbank5_a_air                                   -0.002809
# secondary_cleaner.state.floatbank5_a_level                                  0.123209
# secondary_cleaner.state.floatbank5_b_air                                    0.059332
# secondary_cleaner.state.floatbank5_b_level                                  0.095421
# secondary_cleaner.state.floatbank6_a_air                                    0.177334
# secondary_cleaner.state.floatbank6_a_level                                  0.202164
# final.output.recovery                                                       0.059466
# rougher.output.recovery                                                     0.046994
#
#                                             primary_cleaner.state.floatbank8_c_air  \
# primary_cleaner.input.sulfate                                             0.080308
# primary_cleaner.input.depressant                                         -0.102834
# primary_cleaner.input.feed_size                                          -0.129807
# primary_cleaner.input.xanthate                                            0.058347
# primary_cleaner.state.floatbank8_a_air                                    0.932321
# primary_cleaner.state.floatbank8_a_level                                  0.156841
# primary_cleaner.state.floatbank8_b_air                                    0.943508
# primary_cleaner.state.floatbank8_b_level                                  0.168210
# primary_cleaner.state.floatbank8_c_air                                    1.000000
# primary_cleaner.state.floatbank8_c_level                                  0.167642
# primary_cleaner.state.floatbank8_d_air                                    0.329071
# primary_cleaner.state.floatbank8_d_level                                  0.071275
# rougher.input.feed_ag                                                     0.190820
# rougher.input.feed_pb                                                     0.060318
# rougher.input.feed_rate                                                  -0.091423
# rougher.input.feed_size                                                   0.044709
# rougher.input.feed_sol                                                    0.094840
# rougher.input.feed_au                                                     0.110423
# rougher.input.floatbank10_sulfate                                        -0.068872
# rougher.input.floatbank10_xanthate                                        0.018010
# rougher.input.floatbank11_sulfate                                        -0.073935
# rougher.input.floatbank11_xanthate                                       -0.005472
# rougher.state.floatbank10_a_air                                           0.469819
# rougher.state.floatbank10_a_level                                         0.317663
# rougher.state.floatbank10_b_air                                           0.141202
# rougher.state.floatbank10_b_level                                         0.296801
# rougher.state.floatbank10_c_air                                           0.089202
# rougher.state.floatbank10_c_level                                         0.284372
# rougher.state.floatbank10_d_air                                           0.101355
# rougher.state.floatbank10_d_level                                         0.284111
# rougher.state.floatbank10_e_air                                           0.182019
# rougher.state.floatbank10_e_level                                         0.293223
# rougher.state.floatbank10_f_air                                           0.207231
# rougher.state.floatbank10_f_level                                         0.294551
# secondary_cleaner.state.floatbank2_a_air                                  0.318916
# secondary_cleaner.state.floatbank2_a_level                               -0.057891
# secondary_cleaner.state.floatbank2_b_air                                  0.305639
# secondary_cleaner.state.floatbank2_b_level                               -0.022792
# secondary_cleaner.state.floatbank3_a_air                                  0.471440
# secondary_cleaner.state.floatbank3_a_level                                0.279390
# secondary_cleaner.state.floatbank3_b_air                                  0.326929
# secondary_cleaner.state.floatbank3_b_level                                0.005080
# secondary_cleaner.state.floatbank4_a_air                                  0.585034
# secondary_cleaner.state.floatbank4_a_level                                0.313324
# secondary_cleaner.state.floatbank4_b_air                                  0.578804
# secondary_cleaner.state.floatbank4_b_level                                0.205733
# secondary_cleaner.state.floatbank5_a_air                                  0.593364
# secondary_cleaner.state.floatbank5_a_level                                0.222692
# secondary_cleaner.state.floatbank5_b_air                                  0.547838
# secondary_cleaner.state.floatbank5_b_level                                0.224457
# secondary_cleaner.state.floatbank6_a_air                                  0.273108
# secondary_cleaner.state.floatbank6_a_level                                0.042800
# final.output.recovery                                                     0.190370
# rougher.output.recovery                                                   0.123212
#
#                                             primary_cleaner.state.floatbank8_c_level  \
# primary_cleaner.input.sulfate                                              -0.051234
# primary_cleaner.input.depressant                                            0.124164
# primary_cleaner.input.feed_size                                             0.068863
# primary_cleaner.input.xanthate                                              0.015395
# primary_cleaner.state.floatbank8_a_air                                      0.175949
# primary_cleaner.state.floatbank8_a_level                                    0.964250
# primary_cleaner.state.floatbank8_b_air                                      0.147364
# primary_cleaner.state.floatbank8_b_level                                    0.969770
# primary_cleaner.state.floatbank8_c_air                                      0.167642
# primary_cleaner.state.floatbank8_c_level                                    1.000000
# primary_cleaner.state.floatbank8_d_air                                     -0.427174
# primary_cleaner.state.floatbank8_d_level                                    0.731475
# rougher.input.feed_ag                                                       0.015225
# rougher.input.feed_pb                                                      -0.047594
# rougher.input.feed_rate                                                     0.030546
# rougher.input.feed_size                                                    -0.013914
# rougher.input.feed_sol                                                     -0.157287
# rougher.input.feed_au                                                      -0.051739
# rougher.input.floatbank10_sulfate                                          -0.161337
# rougher.input.floatbank10_xanthate                                          0.233110
# rougher.input.floatbank11_sulfate                                          -0.157179
# rougher.input.floatbank11_xanthate                                          0.221185
# rougher.state.floatbank10_a_air                                            -0.029286
# rougher.state.floatbank10_a_level                                          -0.188125
# rougher.state.floatbank10_b_air                                             0.228176
# rougher.state.floatbank10_b_level                                          -0.062201
# rougher.state.floatbank10_c_air                                             0.178664
# rougher.state.floatbank10_c_level                                          -0.088022
# rougher.state.floatbank10_d_air                                             0.269593
# rougher.state.floatbank10_d_level                                          -0.090752
# rougher.state.floatbank10_e_air                                             0.296776
# rougher.state.floatbank10_e_level                                          -0.079098
# rougher.state.floatbank10_f_air                                             0.341905
# rougher.state.floatbank10_f_level                                          -0.088026
# secondary_cleaner.state.floatbank2_a_air                                    0.147977
# secondary_cleaner.state.floatbank2_a_level                                  0.203773
# secondary_cleaner.state.floatbank2_b_air                                    0.224338
# secondary_cleaner.state.floatbank2_b_level                                  0.184620
# secondary_cleaner.state.floatbank3_a_air                                   -0.001563
# secondary_cleaner.state.floatbank3_a_level                                  0.085939
# secondary_cleaner.state.floatbank3_b_air                                    0.221861
# secondary_cleaner.state.floatbank3_b_level                                  0.175393
# secondary_cleaner.state.floatbank4_a_air                                   -0.048944
# secondary_cleaner.state.floatbank4_a_level                                  0.064128
# secondary_cleaner.state.floatbank4_b_air                                    0.097624
# secondary_cleaner.state.floatbank4_b_level                                 -0.038589
# secondary_cleaner.state.floatbank5_a_air                                   -0.003698
# secondary_cleaner.state.floatbank5_a_level                                  0.116624
# secondary_cleaner.state.floatbank5_b_air                                    0.056666
# secondary_cleaner.state.floatbank5_b_level                                  0.089819
# secondary_cleaner.state.floatbank6_a_air                                    0.172507
# secondary_cleaner.state.floatbank6_a_level                                  0.196406
# final.output.recovery                                                       0.062179
# rougher.output.recovery                                                     0.049615
#
#                                             ...  \
# primary_cleaner.input.sulfate               ...
# primary_cleaner.input.depressant            ...
# primary_cleaner.input.feed_size             ...
# primary_cleaner.input.xanthate              ...
# primary_cleaner.state.floatbank8_a_air      ...
# primary_cleaner.state.floatbank8_a_level    ...
# primary_cleaner.state.floatbank8_b_air      ...
# primary_cleaner.state.floatbank8_b_level    ...
# primary_cleaner.state.floatbank8_c_air      ...
# primary_cleaner.state.floatbank8_c_level    ...
# primary_cleaner.state.floatbank8_d_air      ...
# primary_cleaner.state.floatbank8_d_level    ...
# rougher.input.feed_ag                       ...
# rougher.input.feed_pb                       ...
# rougher.input.feed_rate                     ...
# rougher.input.feed_size                     ...
# rougher.input.feed_sol                      ...
# rougher.input.feed_au                       ...
# rougher.input.floatbank10_sulfate           ...
# rougher.input.floatbank10_xanthate          ...
# rougher.input.floatbank11_sulfate           ...
# rougher.input.floatbank11_xanthate          ...
# rougher.state.floatbank10_a_air             ...
# rougher.state.floatbank10_a_level           ...
# rougher.state.floatbank10_b_air             ...
# rougher.state.floatbank10_b_level           ...
# rougher.state.floatbank10_c_air             ...
# rougher.state.floatbank10_c_level           ...
# rougher.state.floatbank10_d_air             ...
# rougher.state.floatbank10_d_level           ...
# rougher.state.floatbank10_e_air             ...
# rougher.state.floatbank10_e_level           ...
# rougher.state.floatbank10_f_air             ...
# rougher.state.floatbank10_f_level           ...
# secondary_cleaner.state.floatbank2_a_air    ...
# secondary_cleaner.state.floatbank2_a_level  ...
# secondary_cleaner.state.floatbank2_b_air    ...
# secondary_cleaner.state.floatbank2_b_level  ...
# ...
# rougher.input.feed_sol                                                     -0.125534
# rougher.input.feed_au                                                       0.089028
# rougher.input.floatbank10_sulfate                                          -0.062593
# rougher.input.floatbank10_xanthate                                         -0.321913
# rougher.input.floatbank11_sulfate                                          -0.059706
# rougher.input.floatbank11_xanthate                                         -0.309098
# rougher.state.floatbank10_a_air                                             0.037895
# rougher.state.floatbank10_a_level                                          -0.214375
# rougher.state.floatbank10_b_air                                             0.354287
# rougher.state.floatbank10_b_level                                           0.465563
# rougher.state.floatbank10_c_air                                             0.390578
# rougher.state.floatbank10_c_level                                           0.468485
# rougher.state.floatbank10_d_air                                             0.352390
# rougher.state.floatbank10_d_level                                           0.470019
# rougher.state.floatbank10_e_air                                             0.173772
# rougher.state.floatbank10_e_level                                           0.474262
# rougher.state.floatbank10_f_air                                             0.200383
# rougher.state.floatbank10_f_level                                           0.480227
# secondary_cleaner.state.floatbank2_a_air                                    0.010280
# secondary_cleaner.state.floatbank2_a_level                                  0.008659
# secondary_cleaner.state.floatbank2_b_air                                    0.002352
# secondary_cleaner.state.floatbank2_b_level                                  0.043289
# secondary_cleaner.state.floatbank3_a_air                                    0.346112
# secondary_cleaner.state.floatbank3_a_level                                  0.496146
# secondary_cleaner.state.floatbank3_b_air                                    0.366112
# secondary_cleaner.state.floatbank3_b_level                                  0.188041
# secondary_cleaner.state.floatbank4_a_air                                    0.182320
# secondary_cleaner.state.floatbank4_a_level                                  0.566405
# secondary_cleaner.state.floatbank4_b_air                                    0.296251
# secondary_cleaner.state.floatbank4_b_level                                  0.264232
# secondary_cleaner.state.floatbank5_a_air                                    0.390884
# secondary_cleaner.state.floatbank5_a_level                                  0.513831
# secondary_cleaner.state.floatbank5_b_air                                    0.443646
# secondary_cleaner.state.floatbank5_b_level                                  0.497107
# secondary_cleaner.state.floatbank6_a_air                                    1.000000
# secondary_cleaner.state.floatbank6_a_level                                  0.100239
# final.output.recovery                                                      -0.001642
# rougher.output.recovery                                                    -0.013317
#
#                                             secondary_cleaner.state.floatbank6_a_level  \
# primary_cleaner.input.sulfate                                                -0.157876
# primary_cleaner.input.depressant                                             -0.127655
# primary_cleaner.input.feed_size                                               0.067740
# primary_cleaner.input.xanthate                                               -0.086638
# primary_cleaner.state.floatbank8_a_air                                        0.053628
# primary_cleaner.state.floatbank8_a_level                                      0.196568
# primary_cleaner.state.floatbank8_b_air                                        0.032760
# primary_cleaner.state.floatbank8_b_level                                      0.202164
# primary_cleaner.state.floatbank8_c_air                                        0.042800
# primary_cleaner.state.floatbank8_c_level                                      0.196406
# primary_cleaner.state.floatbank8_d_air                                       -0.120255
# primary_cleaner.state.floatbank8_d_level                                      0.185676
# rougher.input.feed_ag                                                        -0.118261
# rougher.input.feed_pb                                                        -0.123207
# rougher.input.feed_rate                                                       0.026219
# rougher.input.feed_size                                                       0.065105
# rougher.input.feed_sol                                                       -0.029641
# rougher.input.feed_au                                                        -0.175860
# rougher.input.floatbank10_sulfate                                            -0.039821
# rougher.input.floatbank10_xanthate                                           -0.001330
# rougher.input.floatbank11_sulfate                                            -0.040832
# rougher.input.floatbank11_xanthate                                           -0.000453
# rougher.state.floatbank10_a_air                                              -0.030282
# rougher.state.floatbank10_a_level                                             0.108437
# rougher.state.floatbank10_b_air                                               0.166726
# rougher.state.floatbank10_b_level                                             0.191783
# rougher.state.floatbank10_c_air                                               0.138872
# rougher.state.floatbank10_c_level                                             0.191347
# rougher.state.floatbank10_d_air                                               0.137615
# rougher.state.floatbank10_d_level                                             0.193464
# rougher.state.floatbank10_e_air                                               0.194317
# rougher.state.floatbank10_e_level                                             0.182705
# rougher.state.floatbank10_f_air                                               0.204135
# rougher.state.floatbank10_f_level                                             0.180738
# secondary_cleaner.state.floatbank2_a_air                                      0.015646
# secondary_cleaner.state.floatbank2_a_level                                    0.133927
# secondary_cleaner.state.floatbank2_b_air                                     -0.047772
# secondary_cleaner.state.floatbank2_b_level                                    0.140060
# secondary_cleaner.state.floatbank3_a_air                                     -0.038669
# secondary_cleaner.state.floatbank3_a_level                                    0.306307
# secondary_cleaner.state.floatbank3_b_air                                     -0.059159
# secondary_cleaner.state.floatbank3_b_level                                    0.296449
# secondary_cleaner.state.floatbank4_a_air                                     -0.007955
# secondary_cleaner.state.floatbank4_a_level                                    0.270404
# secondary_cleaner.state.floatbank4_b_air                                     -0.119069
# secondary_cleaner.state.floatbank4_b_level                                    0.291952
# secondary_cleaner.state.floatbank5_a_air                                     -0.010217
# secondary_cleaner.state.floatbank5_a_level                                    0.383423
# secondary_cleaner.state.floatbank5_b_air                                     -0.034457
# secondary_cleaner.state.floatbank5_b_level                                    0.346970
# secondary_cleaner.state.floatbank6_a_air                                      0.100239
# secondary_cleaner.state.floatbank6_a_level                                    1.000000
# final.output.recovery                                                        -0.063354
# rougher.output.recovery                                                      -0.057998
#
#                                             final.output.recovery  \
# primary_cleaner.input.sulfate                            0.399741
# primary_cleaner.input.depressant                         0.144982
# primary_cleaner.input.feed_size                          0.040477
# primary_cleaner.input.xanthate                           0.189955
# primary_cleaner.state.floatbank8_a_air                   0.183474
# primary_cleaner.state.floatbank8_a_level                 0.066636
# primary_cleaner.state.floatbank8_b_air                   0.194162
# primary_cleaner.state.floatbank8_b_level                 0.059466
# primary_cleaner.state.floatbank8_c_air                   0.190370
# primary_cleaner.state.floatbank8_c_level                 0.062179
# primary_cleaner.state.floatbank8_d_air                   0.073566
# primary_cleaner.state.floatbank8_d_level                -0.019351
# rougher.input.feed_ag                                    0.346688
# rougher.input.feed_pb                                    0.228626
# rougher.input.feed_rate                                  0.148034
# rougher.input.feed_size                                  0.074806
# rougher.input.feed_sol                                   0.262918
# rougher.input.feed_au                                    0.332646
# rougher.input.floatbank10_sulfate                       -0.053624
# rougher.input.floatbank10_xanthate                       0.318143
# rougher.input.floatbank11_sulfate                       -0.040881
# rougher.input.floatbank11_xanthate                       0.311388
# rougher.state.floatbank10_a_air                          0.247512
# rougher.state.floatbank10_a_level                        0.106273
# rougher.state.floatbank10_b_air                         -0.146441
# rougher.state.floatbank10_b_level                       -0.086467
# rougher.state.floatbank10_c_air                         -0.195596
# rougher.state.floatbank10_c_level                       -0.099785
# rougher.state.floatbank10_d_air                         -0.184994
# rougher.state.floatbank10_d_level                       -0.097327
# rougher.state.floatbank10_e_air                         -0.135879
# rougher.state.floatbank10_e_level                       -0.101089
# rougher.state.floatbank10_f_air                         -0.089750
# rougher.state.floatbank10_f_level                       -0.101208
# secondary_cleaner.state.floatbank2_a_air                 0.213183
# secondary_cleaner.state.floatbank2_a_level              -0.014657
# secondary_cleaner.state.floatbank2_b_air                 0.177387
# secondary_cleaner.state.floatbank2_b_level               0.004405
# secondary_cleaner.state.floatbank3_a_air                 0.231448
# secondary_cleaner.state.floatbank3_a_level               0.032276
# secondary_cleaner.state.floatbank3_b_air                 0.058812
# secondary_cleaner.state.floatbank3_b_level               0.003384
# secondary_cleaner.state.floatbank4_a_air                 0.272288
# secondary_cleaner.state.floatbank4_a_level               0.063144
# secondary_cleaner.state.floatbank4_b_air                 0.224037
# secondary_cleaner.state.floatbank4_b_level              -0.107897
# secondary_cleaner.state.floatbank5_a_air                 0.154034
# secondary_cleaner.state.floatbank5_a_level               0.033607
# secondary_cleaner.state.floatbank5_b_air                 0.115537
# secondary_cleaner.state.floatbank5_b_level               0.055457
# secondary_cleaner.state.floatbank6_a_air                -0.001642
# secondary_cleaner.state.floatbank6_a_level              -0.063354
# final.output.recovery                                    1.000000
# rougher.output.recovery                                  0.395207
#
#                                             rougher.output.recovery
# primary_cleaner.input.sulfate                              0.304197
# primary_cleaner.input.depressant                           0.025652
# primary_cleaner.input.feed_size                           -0.010591
# primary_cleaner.input.xanthate                             0.103295
# primary_cleaner.state.floatbank8_a_air                     0.096616
# primary_cleaner.state.floatbank8_a_level                   0.049533
# primary_cleaner.state.floatbank8_b_air                     0.107642
# primary_cleaner.state.floatbank8_b_level                   0.046994
# primary_cleaner.state.floatbank8_c_air                     0.123212
# primary_cleaner.state.floatbank8_c_level                   0.049615
# primary_cleaner.state.floatbank8_d_air                     0.006533
# primary_cleaner.state.floatbank8_d_level                   0.021422
# rougher.input.feed_ag                                      0.216437
# rougher.input.feed_pb                                      0.193089
# rougher.input.feed_rate                                    0.078423
# rougher.input.feed_size                                    0.084331
# rougher.input.feed_sol                                     0.191280
# rougher.input.feed_au                                      0.181276
# rougher.input.floatbank10_sulfate                         -0.160754
# rougher.input.floatbank10_xanthate                         0.249873
# rougher.input.floatbank11_sulfate                         -0.149942
# rougher.input.floatbank11_xanthate                         0.239613
# rougher.state.floatbank10_a_air                            0.230512
# rougher.state.floatbank10_a_level                          0.164248
# rougher.state.floatbank10_b_air                           -0.120845
# rougher.state.floatbank10_b_level                         -0.116981
# rougher.state.floatbank10_c_air                           -0.160232
# rougher.state.floatbank10_c_level                         -0.119020
# rougher.state.floatbank10_d_air                           -0.144191
# rougher.state.floatbank10_d_level                         -0.119329
# rougher.state.floatbank10_e_air                           -0.108479
# rougher.state.floatbank10_e_level                         -0.117100
# rougher.state.floatbank10_f_air                           -0.058216
# rougher.state.floatbank10_f_level                         -0.116174
# secondary_cleaner.state.floatbank2_a_air                   0.204977
# secondary_cleaner.state.floatbank2_a_level                -0.021381
# secondary_cleaner.state.floatbank2_b_air                   0.177351
# secondary_cleaner.state.floatbank2_b_level                -0.009383
# secondary_cleaner.state.floatbank3_a_air                   0.208837
# secondary_cleaner.state.floatbank3_a_level                -0.010294
# secondary_cleaner.state.floatbank3_b_air                   0.045792
# secondary_cleaner.state.floatbank3_b_level                -0.043550
# secondary_cleaner.state.floatbank4_a_air                   0.289139
# secondary_cleaner.state.floatbank4_a_level                 0.044429
# secondary_cleaner.state.floatbank4_b_air                   0.271372
# secondary_cleaner.state.floatbank4_b_level                -0.086671
# secondary_cleaner.state.floatbank5_a_air                   0.199522
# secondary_cleaner.state.floatbank5_a_level                -0.005272
# secondary_cleaner.state.floatbank5_b_air                   0.182483
# secondary_cleaner.state.floatbank5_b_level                 0.023238
# secondary_cleaner.state.floatbank6_a_air                  -0.013317
# secondary_cleaner.state.floatbank6_a_level                -0.057998
# final.output.recovery                                      0.395207
# rougher.output.recovery                                    1.000000
#
# [54 rows x 54 columns]

# %%
corr['final.output.recovery'].describe()
# Out:
# count    54.000000
# mean      0.101413
# std       0.198481
# min      -0.195596
# 25%      -0.035499
# 50%       0.064890
# 75%       0.208428
# max       1.000000
# Name: final.output.recovery, dtype: float64

# %% [markdown]
# Для обучения моделей, используем те признаки, корреляция которых к целевым > 0.1

# %% [markdown]
# 3.2.2 Разделим признаки в выборках на целевые и необходимые для обучения

# %%
X_col_rougher_cor = corr[corr['rougher.output.recovery'] > 0.1].drop(['rougher.output.recovery', 'final.output.recovery'])
X_col_rougher_cor.index
# Out:
# Index(['primary_cleaner.input.sulfate', 'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_c_air', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_sol',
#        'rougher.input.feed_au', 'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
#        'rougher.state.floatbank10_a_level',
#        'secondary_cleaner.state.floatbank2_a_air',
#        'secondary_cleaner.state.floatbank2_b_air',
#        'secondary_cleaner.state.floatbank3_a_air',
#        'secondary_cleaner.state.floatbank4_a_air',
#        'secondary_cleaner.state.floatbank4_b_air',
#        'secondary_cleaner.state.floatbank5_a_air',
#        'secondary_cleaner.state.floatbank5_b_air'],
#       dtype='object')

# %% [markdown]
# Для предсказаний эффективности после флотации используем признаки, участвующие в данной процедуре

# %%
X_col_rougher = X_col_rougher_cor.index[4:12]
X_col_rougher
# Out:
# Index(['rougher.input.feed_ag', 'rougher.input.feed_pb',
#        'rougher.input.feed_sol', 'rougher.input.feed_au',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
#        'rougher.state.floatbank10_a_level'],
#       dtype='object')

# %%
X_col_final = corr[corr['final.output.recovery'] > 0.1].drop(['rougher.output.recovery', 'final.output.recovery']).index
X_col_final
# Out:
# Index(['primary_cleaner.input.sulfate', 'primary_cleaner.input.depressant',
#        'primary_cleaner.input.xanthate',
#        'primary_cleaner.state.floatbank8_a_air',
#        'primary_cleaner.state.floatbank8_b_air',
#        'primary_cleaner.state.floatbank8_c_air', 'rougher.input.feed_ag',
#        'rougher.input.feed_pb', 'rougher.input.feed_rate',
#        'rougher.input.feed_sol', 'rougher.input.feed_au',
#        'rougher.input.floatbank10_xanthate',
#        'rougher.input.floatbank11_xanthate', 'rougher.state.floatbank10_a_air',
#        'rougher.state.floatbank10_a_level',
#        'secondary_cleaner.state.floatbank2_a_air',
#        'secondary_cleaner.state.floatbank2_b_air',
#        'secondary_cleaner.state.floatbank3_a_air',
#        'secondary_cleaner.state.floatbank4_a_air',
#        'secondary_cleaner.state.floatbank4_b_air',
#        'secondary_cleaner.state.floatbank5_a_air',
#        'secondary_cleaner.state.floatbank5_b_air'],
#       dtype='object')

# %%
def X_y(data):
    X_rougher = data[X_col_rougher]
    y_rougher = data['rougher.output.recovery']
    X_final = data[X_col_final]
    y_final = data['final.output.recovery']
    return X_rougher, y_rougher, X_final, y_final

# %%
X_train_rougher, y_train_rougher, X_train_final, y_train_final = X_y(train)
X_test_rougher, y_test_rougher, X_test_final, y_test_final = X_y(test)

# %% [markdown]
# 3.2.2 Для обучения выберем модели LinearRegression, DecisionTreeRegressor, RandomForestRegressor, GradientBoostingRegressor

# %%
model_linear = LinearRegression()
model_tree = DecisionTreeRegressor(random_state=42)
model_forest = RandomForestRegressor(random_state=42)
model_boost = GradientBoostingRegressor(random_state=42)

# %%
def score(model):
    score_rougher = cross_val_score(model, X_train_rougher, y_train_rougher, cv=5, scoring=my_scorer).mean()
    score_final = cross_val_score(model, X_train_final, y_train_final, cv=5, scoring=my_scorer).mean()
    print('smape чернового концентрата:', score_rougher)
    print('smape финального концентрата:', score_final)
    print('итоговый smape:', ((0.25 * score_rougher) + (0.75 * score_final)))

# %%
score(model_linear)
# Out:
# smape чернового концентрата: 10.170118497279862
# smape финального концентрата: 9.496202342224743
# итоговый smape: 9.664681380988522

# %%
score(model_tree)
# Out:
# smape чернового концентрата: 13.506174839257502
# smape финального концентрата: 16.06225283966981
# итоговый smape: 15.423233339566734

# %%
score(model_forest)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# smape чернового концентрата: 11.328879298641983
# smape финального концентрата: 11.301195857885798
# итоговый smape: 11.308116718074842

# %%
score(model_boost)
# Out:
# smape чернового концентрата: 9.692709555624386
# smape финального концентрата: 9.667531135398132
# итоговый smape: 9.673825740454696

# %% [markdown]
# Продолжим с моделью GradientBoostingRegressor

# %% [markdown]
# Улучшим модель с помощью подбора гиперпараметров

# %% [markdown]
# Чтобы использовать GridSearchCV необходимо изменить параметры метрики my_scorer

# %%
my_scorer_1 = make_scorer(smape, greater_is_better=False)

# %%
param_grid = {
    'n_estimators': [i for i in range(50, 150, 10)],
    'max_depth': [i for i in range(2,5)]
}
search = GridSearchCV(model_boost, param_grid, cv=3, scoring=my_scorer_1)
search.fit(X_train_final, y_train_final)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=GradientBoostingRegressor(alpha=0.9,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_no_change=None,
#                                                  presort='auto',
#                                                  random_state=42, subsample=1.0,
#                                                  tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_depth': [2, 3, 4],
#                          'n_estimators': [50, 60, 70, 80, 90, 100, 110, 120,
#                                           130, 140]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=make_scorer(smape, greater_is_better=False), verbose=0)

# %%
search.best_params_
# Out:
# {'max_depth': 2, 'n_estimators': 50}

# %%
search.best_score_
# Out:
# -9.47804903529843

# %% [markdown]
# 3.2.3 Проверим модель на тестовой выборке с подобранными гиперпараметрами

# %%
def predict(X_test_r, X_test_f):
    model_boost_rougher = GradientBoostingRegressor(random_state=42, n_estimators=50, max_depth=2)
    model_boost_final = GradientBoostingRegressor(random_state=42, n_estimators=50, max_depth=2)
    model_boost_rougher.fit(X_train_rougher, y_train_rougher)
    model_boost_final.fit(X_train_final, y_train_final)
    pred_rougher = model_boost_rougher.predict(X_test_r)
    pred_final = model_boost_final.predict(X_test_f)
    return pred_rougher, pred_final

# %%
pred_rougher, pred_final = predict(X_test_rougher, X_test_final)

# %%
print('smape чернового концентрата:', smape(y_test_rougher, pred_rougher))
print('smape финального концентрата:', smape(y_test_final, pred_final))
print('итоговый smape:', ((0.25 * smape(y_test_rougher, pred_rougher)) + 0.75 * smape(y_test_final, pred_final)))
# Out:
# smape чернового концентрата: 7.882775432655391
# smape финального концентрата: 8.364135089926316
# итоговый smape: 8.243795175608586

# %% [markdown]
# 3.2.4 Создадим константную модель для оценки адекватности моделей

# %%
pred_rougher_cons = pd.Series(y_train_rougher.mean(), index=y_test_rougher.index)
pred_final_cons = pd.Series(y_train_final.mean(), index=y_test_final.index)

# %%
print('smape чернового концентрата:', smape(y_test_rougher, pred_rougher_cons))
print('smape финального концентрата:', smape(y_test_final, pred_final_cons))
print('итоговый smape:', ((0.25 * smape(y_test_rougher, pred_rougher_cons) + 0.75 * smape(y_test_final, pred_final_cons))))
# Out:
# smape чернового концентрата: 9.974748935440875
# smape финального концентрата: 9.552398344041567
# итоговый smape: 9.657985991891394

# %% [markdown]
# #### Вывод
# 1. Выполнили предобработку данных. Подготовили их к дальнейшей работе
# 2. Провели исследовательский анализ данных
# 3. Обучили модели
# 4. Лучшей моделью оказалась GradientBoostingRegressor с результатом 8.24%
# 5. Сравнили модель с константной. Результат константной модели 9,65% против 8.24%.
